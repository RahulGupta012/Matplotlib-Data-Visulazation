# %% [markdown]
#                                               ASSIGNMNET: MATPLOTLIB

# %% [markdown]
# Q1: What is Matplotlib? Why is it used? Name five plots that can be plotted using the Pyplot module of
# Matplotlib.

# %% [markdown]
# Matplotlib basically a librarary for data visulazation. It has numeries functions for genrting the various type of graphs for various types of data. By using this type of lib, we used to read the data just by glacing it.
# There are the name of five plots that an be plotted using the pyplot;
# 1. plot()
# 2. scatter()
# 3. bar()
# 4. barh()
# 5. hist()

# %% [markdown]
# Q2: What is a scatter plot? Use the following code to generate data for x and y. Using this generated data
# plot a scatter plot.
#
# import numpy as np
# np.random.seed(3)
#
# - x = 3 + np.random.normal(0, 2, 50)
# - y = 3 + np.random.normal(0, 2, len(x))
#
# Note: Also add title, xlabel, and ylabel to the plot.

# %%
import numpy as np
np.random.seed(3)
x = 3 + np.random.normal(0, 2, 50)
y = 3 + np.random.normal(0, 2, len(x))

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(x,y)
plt.xlabel('This is x axis')
plt.ylabel('This is y axis')
plt.title('This is title')
# Out:
# Text(0.5, 1.0, 'This is title')

# %% [markdown]
# Q3: Why is the subplot() function used? Draw four line plots using the subplot() function.
# Use the following data:

# %%
import numpy as np
x = np.array([0, 1, 2, 3, 4, 5]) 
y = np.array([0, 100, 200, 300, 400, 500])

x = np.array([0, 1, 2, 3, 4, 5]) 
y = np.array([50, 20, 40, 20, 60, 70])

x = np.array([0, 1, 2, 3, 4, 5]) 
y = np.array([10, 20, 30, 40, 50, 60])

x = np.array([0, 1, 2, 3, 4, 5]) 
y = np.array([200, 350, 250, 550, 450, 150])

# %%
import numpy as np
x = np.array([0, 1, 2, 3, 4, 5]) 
y = np.array([0, 100, 200, 300, 400, 500])

plt.subplot(221)
plt.plot(x,y)

x = np.array([0, 1, 2, 3, 4, 5]) 
y = np.array([50, 20, 40, 20, 60, 70])

plt.subplot(222)
plt.plot(x,y)

x = np.array([0, 1, 2, 3, 4, 5]) 
y = np.array([10, 20, 30, 40, 50, 60])

plt.subplot(223)
plt.plot(x,y)

x = np.array([0, 1, 2, 3, 4, 5]) 
y = np.array([200, 350, 250, 550, 450, 150])

plt.subplot(224)
plt.plot(x,y)

# %% [markdown]
# Q4: What is a bar plot? Why is it used? Using the following data plot a bar plot and a horizontal bar plot.
# import numpy as np
#
# company = np.array(["Apple", "Microsoft", "Google", "AMD"])
#
# profit = np.array([3000, 8000, 1000, 10000])

# %%
import numpy as np
company = np.array(["Apple", "Microsoft", "Google", "AMD"])
profit = np.array([3000, 8000, 1000, 10000])

# %%
#bar plot is given a graph, which shows the values for a specific key's increment or decrement
import matplotlib.pyplot as plt
plt.barh(company, profit)
# Out:
# <BarContainer object of 4 artists>

# %% [markdown]
# Q5: What is a box plot? Why is it used? Using the following data plot a box plot.

# %%
import numpy as np
box1 = np.random.normal(100, 10, 200)
box2 = np.random.normal(90, 20, 200)
box= [box1,box2]

# %%
import matplotlib.pyplot as plt

# %%
fig= plt.figure()
axe= fig.add_axes([0,0,1,1])
axe.boxplot(box)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7fcc8e6679d0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7fcc8e667f10>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7fcc8e667730>,
# ...
#  'medians': [<matplotlib.lines.Line2D at 0x7fcc8e680490>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x7fcc8e680730>,
# ...
#  'means': []}
